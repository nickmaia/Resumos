# %% [markdown]
# ---

# %% [markdown]
# <h2 align="center" style="color:gray"> # [1] Modelagem de sistemas a parâmetros concentrados
# </h2>

# %% [markdown]
# ---

# %% [markdown]
# ### [1] Representação de modelos em espaço de estados

# %% [markdown]
# Considere o modelo dinâmico geral da seguinte forma:
# ### $$\dot{𝑥} = 𝑓(𝑥, 𝑢)$$
#
# - 𝑓(𝑥, 𝑢) é um vetor de funções lineares.
#
# Uma maneira de representar modelos lineares, é a utilização do mesmo em espaço de estados, que possui a forma geral:
# ### $$\dot{𝑥} = 𝑨𝒙 + 𝑩𝒖 \\
# 𝒚 = 𝑪𝒙 + 𝑫𝒖 $$
#
# em que:
# - x: são os estados;
# - u: são as entradas (variáveis manipuladas);
# - y: são as saídas (variáveis controladas);
# - A: matriz de estados do modelo;
# - B: matriz de entradas do modelo;
# - C: matriz de saídas do modelo;
# - D: matriz que possui a contribuição (peso, influência) das variáveis de entrada na saída do modelo.

# %% [markdown]
# ### [2] Forma Geral dos Modelos em Espaços de Estados

# %% [markdown]
# ![image.png](attachment:a3762b24-7d32-40d1-a7c3-46a4bf36aced.png)

# %% [markdown]
# Em que tem-se:
# - n estados (x)
# - m variáveis de entrada (u)
# - r variáveis de saída (y)

# %% [markdown]
# ![image.png](attachment:767c7a8f-1ffb-48ec-852f-cbad3d29a3a9.png)

# %% [markdown]
# ### [Exemplo]: Dois tanques em série

# %% [markdown]
# ![image.png](attachment:e881ba7f-ff15-453c-9681-95743ac6f755.png)

# %% [markdown]
# ### [3] Modelagem a parâmetros concentrados

# %% [markdown]
# ![image.png](attachment:b1372694-e3a1-413a-bd2c-d8415d279673.png)

# %% [markdown]
# ![image.png](attachment:d6381cf1-f8a5-4141-86b6-3d8ea69ac897.png)

# %% [markdown]
# ### [4] BALANÇO DE QUANTIDADE DE MOVIMENTO
# - O balanço de quantidade de movimento ocorre em sistemas mecânicos e de fluxo, em que várias forças atuam como: forças gravitacionais; cisalhantes; viscosas e de pressão.

# %% [markdown]
# ![image.png](attachment:700fa31c-2644-40d4-9c46-5a3f5b2f0e7d.png)

# %% [markdown]
# ### [5] Procedimento
# 1. Modelar o balanço de massa - testar o modelo;
# 2. Adicionar o balanço de energia conforme necessário - testar o modelo;
# 3. Adicionar as malhas de controle uma de cada vez - sintonizar e testar;
# 4. Testar o modelo integrado global;
# 5. Documentar o modelo desenvolvido:
#
#       a. Objetivos e hipóteses;
#
#       b. Diagrama de balanços;
#
#       c. Valores de parâmetros e dados de referência;
#
#       d. Desenvolvimento das equações;
#
#       e. Dados de testes de desempenho do modelo;
#
# 6. Usar o modelo para o objetivo desejado (área).

# %% [markdown]
# ### [6] Exercício

# %% [markdown]
# ![image.png](attachment:a9375d4a-4b06-40b2-a96a-d3f8d79493b6.png)

# %% [markdown]
# ![image.png](attachment:65af9722-4a9a-43ad-8937-3e16b47d588c.png)

# %% [markdown]
# ![image.png](attachment:5126607f-b08d-483c-9542-ee9f2b05b293.png)

# %% [markdown]
# ---

# %% [markdown]
# <h2 align="center" style="color:gray"># [2] Adimensionalização de Modelos</h2>

# %% [markdown]
# ---

# %% [markdown]
# ### [1] Análise dimensional

# %% [markdown]
# A palavra dimensão denota a natureza física de uma grandeza. Por exemplo, não importa se uma distância é medida em metros ou pés, ela é uma distancia e dizemos que sua dimensão é comprimento.
#
# Representação: Considere uma grandeza V do SI, então:
#  #### $$[V]= L^{\alpha}M^{\beta}T^{\gamma }$$
#
# Em que:
# - L: Comprimento
# - M: Massa
# - T: Tempo
# - ${\alpha},{\beta},{\gamma }$ são os expoentes dimensionais
#
# **Obs:** Se os expoentes forem nulos a grandeza é adimensional

# %% [markdown]
# ### [2] Grandezas Derivadas

# %% [markdown]
# As dimensões de uma grandeza determina-se a partir de sua equação de definição através das substituições:
# - L - Comprimento
# - M - Massa
# - T - Tempo
# - $ \theta $ - Temperatura
#
# Estas são denominadas grandezas primárias.
#
# Exemplo:
#
# ![image.png](attachment:f5d9e436-5cba-4632-830b-b37b6bd8dd5d.png)

# %% [markdown]
# ### [3] Modelo Adimensional

# %% [markdown]
# O modelo adimensional é obtido dividindo cada um de seus termos por um grupamento de constantes da mesma dimensão de modo a adimensionalizar.

# %% [markdown]
# ### [4] Procedimento

# %% [markdown]
# 1. Listar a dimensão de todos os parâmetros do modelo.
# 2. Escolher as variáveis de escalonamento devem ser constantes.
# 3. Definir as variáveis adimensionais.
# 4. Reescrever o modelo na sua forma adimensional.

# %% [markdown]
# ### [5] Vantagens da adimensionalização

# %% [markdown]
# 1. Aumenta a compreensão das relações entre os principais parâmetros do problema.
# 2. Reduz o número de parâmetros.
# 3. Pode ser usado para escalonar variáveis com vantagens numéricas.
#
# Exemplo: Um objeto caindo por gravidade no vácuo.
# - CI: Posição inicial Zo e a velocidade inicial Wo
# - Modelo:
# #### $$\frac{d^{2}z}{dt^{2}} = -g$$
#
# 1. Z[L], Zo[L], t[T], g[L/T²], Wo[L/T]
# 2. Variáveis de escalonamento: Wo, Zo, g
# 3. Adimensionais: Z e t
#
# ![image.png](attachment:57cdd254-2657-4aa5-ba4c-a9ee67e40f15.png)

# %% [markdown]
# #### Exemplo 02:
#
# Considere o modelo de um CSTR isotérmico com volume constante dado por:
#
# $$ \frac{dCa}{dt} = \frac{F}{V} (Caf - Ca) - K . Ca$$
#
# Proponha o modelo adimensional e prove que está adimensionalizado.

# %% [markdown]
# ![image.png](attachment:025c759f-05f6-48d3-bc06-ecb4af6b59ef.png)

# %% [markdown]
# ### [6] Exercício em sala - adimensionalização

# %% [markdown]
# ![image.png](attachment:b482059e-1a9e-40cb-9fbb-cac0c7157c11.png)

# %% [markdown]
# <h2 align="center" style="color:gray"> # [3] Desenvolvimento de modelo de
# sistemas a parâmetros
# distribuído
# </h2>

# %% [markdown]
# ## # Balanço de Massa

# %% [markdown]
# ---

# %% [markdown]
# ### <center>  Balanço de Massa Global

# %% [markdown]
# ![image.png](attachment:4ccd926c-0416-4c4a-8d04-0eb8dd2017c6.png)

# %% [markdown]
# ### <center>  Balanço de Massa por Componente

# %% [markdown]
# ![image.png](attachment:7697d633-c7c3-4e21-b8a8-e75ad6aec533.png)

# %% [markdown]
# ### <center>  Balanço de Energia

# %% [markdown]
# ![image.png](attachment:ad13cc11-ec26-46e4-bea0-11bce13a1914.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:c3133d5b-52df-416e-9ba6-3ed48f7af801.png)
# ![image.png](attachment:91d4d90a-4cb4-4d80-8f51-4a9e2353d35d.png)

# %% [markdown]
# ---

# %% [markdown]
# ### # Exercício para Casa

# %% [markdown]
# ![image.png](attachment:733cf518-e7a8-440b-af8a-cd9a09b18049.png)
