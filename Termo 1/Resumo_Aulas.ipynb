# %%
from IPython.display import display, HTML

bootstrap_css = """
<!-- Bootstrap CSS CDN -->

<link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha3/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-KK94CHFLLe+nY2dmCWGMq91rCGa5gtU4mk92HdvYe+M/SXH301p5ILy+dN9+nJOZ" crossorigin="anonymous">
"""

bootstrap_js = """
<!-- Bootstrap JavaScript CDN -->
<script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha3/dist/js/bootstrap.bundle.min.js" integrity="sha384-ENjdO4Dr2bkBIFxQpeoTz1HIcje39Wm4jDKdf19U8gI4ddQ3GYNS7NTKfAdVQSZe" crossorigin="anonymous"></script>
"""

display(HTML(bootstrap_css + bootstrap_js))
# Out:
# <!-- Bootstrap CSS CDN -->
#
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha3/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-KK94CHFLLe+nY2dmCWGMq91rCGa5gtU4mk92HdvYe+M/SXH301p5ILy+dN9+nJOZ" crossorigin="anonymous">
#
# <!-- Bootstrap JavaScript CDN -->
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0-alpha3/dist/js/bootstrap.bundle.min.js" integrity="sha384-ENjdO4Dr2bkBIFxQpeoTz1HIcje39Wm4jDKdf19U8gI4ddQ3GYNS7NTKfAdVQSZe" crossorigin="anonymous"></script>

# %% [markdown]
# ## # Sistemas - Conceitos e aplicações

# %% [markdown]
# ---

# %% [markdown]
# ### Sistemas Termodinâmicos:
#
# <img src="attachment:7be811cb-7293-4ad2-8d00-56cdca006c01.png" alt="..." class="rounded float-end w-25 p-3 img-fluid" >
#
# **Sistemas termodinâmicos**, também conhecidos como **volumes de controle**, são regiões do espaço delimitadas por uma **fronteira**, que pode ser uma superfície real ou imaginária. Essas fronteiras contêm substâncias ou partículas em interação e servem para separar o sistema em estudo do restante do universo, conhecido como **vizinhança**.

# %% [markdown]
# ### Tipos de Sistemas:
#
# <img src="attachment:1b50935a-fad1-4e1d-8751-e777d7d26cbe.png" alt="..." class="rounded float-end" style = "width: 450px;">
#
# - **Sistema aberto:** Este tipo de sistema permite a troca de matéria e energia com suas vizinhanças. Um exemplo comum de um sistema aberto é uma panela de água fervente destampada. Nesse caso, a água (matéria) e o vapor (energia) podem sair da panela e trocar calor com o ambiente.
#
# - **Sistema fechado:** Um sistema fechado permite a troca de energia, como calor e trabalho, mas não permite a troca de matéria com suas vizinhanças. Um exemplo de um sistema fechado é uma lata de refrigerante selada. O refrigerante pode trocar calor com o ambiente, mas a matéria (o líquido e o gás dentro da lata) não pode sair nem entrar no sistema.
#
# - **Sistema isolado:** Esse tipo de sistema não permite trocas de energia nem matéria com suas vizinhanças. Um exemplo de um sistema isolado é uma garrafa térmica, que impede a troca de calor e matéria entre o conteúdo da garrafa e o ambiente externo.

# %% [markdown]
# ### Processos termodinâmicos
# São mudanças de estado que ocorrem dentro do sistema. Essas mudanças podem ser isobáricas, isocóricas, isotérmicas ou adiabáticas, dependendo das variáveis termodinâmicas que permanecem constantes durante o processo.
#
# - **Processo Isobárico:** Um processo isobárico ocorre quando a **``pressão do sistema permanece constante``** durante todo o processo. Um exemplo comum é o aquecimento de um gás dentro de um cilindro com um pistão móvel. À medida que o gás é aquecido, sua temperatura e volume aumentam, mas a pressão permanece constante devido ao ajuste do pistão.
#
# - **Processo Isocórico (ou isovolumétrico):** Neste tipo de processo, o **``volume do sistema permanece constante``** enquanto outras variáveis termodinâmicas, como pressão e temperatura, podem mudar. Um exemplo de um processo isocórico é o aquecimento de um gás em um recipiente rígido e fechado. Como o volume do recipiente não muda, o aumento da temperatura do gás resulta em um aumento da pressão interna.
#
# - **Processo Isotérmico:** Um processo isotérmico ocorre quando a **``temperatura do sistema permanece constante``** durante a mudança de estado. Isso geralmente implica que o sistema está em equilíbrio térmico com o ambiente. Um exemplo de um processo isotérmico é a expansão lenta e controlada de um gás em um cilindro com um pistão móvel, mantendo a temperatura constante através de um banho térmico. Nesse caso, a pressão e o volume do gás mudam, mas a temperatura não.
#
# - **Processo Adiabático:** Um processo adiabático é aquele em que **``não há troca de calor entre o sistema e o ambiente``**. Isso pode ocorrer em sistemas bem isolados ou em processos que ocorrem muito rapidamente, não permitindo tempo suficiente para trocas de calor. Um exemplo de um processo adiabático é a compressão rápida de um gás em um cilindro com um pistão. A rápida compressão resulta em um aumento da temperatura e da pressão do gás, mas sem a troca de calor com o ambiente.

# %% [markdown]
# ###  Estado de um sistema termodinâmico:
# O estado de um sistema termodinâmico é determinado pelos valores das propriedades macroscópicas, como pressão, temperatura, volume e composição química (para misturas), independentemente do caminho percorrido para atingir esses valores. Isso significa que, em termodinâmica, o estado atual do sistema é mais importante do que a sequência de eventos que levou a esse estado.

# %% [markdown]
# ### Classificação do Estado de um Sistema:
#
# - **Estado Estacionário ou Permanente:** Os valores de todas as variáveis do processo (temperatura, pressão, volume, vazões, etc.) ``não variam com o tempo``.
# - **Estado Transiente ou Não-Estacionário:** Pelo menos uma variável do processo ``varia com o tempo``.
#
# **Equilíbrio Termodinâmico:** É o estado em que as variáveis termodinâmicas possuem valores uniformes e estacionários (``não variam com o tempo``) em todo o sistema. É uma condição na qual não há mudanças espontâneas nas propriedades do sistema e, portanto, a ``energia e a matéria`` estão distribuídas de ``forma estável``.

# %% [markdown]
# ### Fases
# Na termodinâmica, a "fase" de uma substância refere-se ao estado físico em que ela se encontra, como sólida, líquida ou gasosa.
#
# As fases mais comuns são:
#
# - **Sólida**: Nesta fase, as partículas (átomos, íons ou moléculas) estão organizadas em uma estrutura cristalina ou amorfa, com forte interação entre as partículas. Os sólidos têm forma e volume definidos e geralmente possuem alta densidade e baixa compressibilidade.
# - **Líquida**: Na fase líquida, as partículas estão mais próximas umas das outras do que na fase gasosa, mas menos organizadas do que na fase sólida. Os líquidos têm volume definido, mas sua forma depende do recipiente em que estão contidos. A densidade dos líquidos é geralmente menor que a dos sólidos e maior que a dos gases, e possuem maior compressibilidade que os sólidos, mas menor que os gases.
# - **Gasosa**: Na fase gasosa, as partículas estão dispersas e se movem livremente, com interações fracas entre elas. Os gases não têm forma nem volume definidos, ocupando todo o espaço disponível no recipiente que os contém. A densidade dos gases é menor do que a dos líquidos e sólidos, e possuem alta compressibilidade.

# %% [markdown]
# ### Mudança de fases
# As mudanças de fase ocorrem quando uma substância passa de um estado físico para outro devido a alterações em variáveis termodinâmicas, como pressão e temperatura.
#
# <img src="attachment:64e7fb5d-056a-4b0d-98c0-7e5bf8d6947b.png" alt="..." class="rounded float-end"  style = "width: 380px;" >
#
# #### Exemplo a Água:
# A **fusão** (passagem do estado sólido para o líquido) ocorre quando a temperatura do sólido atinge seu ponto de fusão sob uma pressão constante. Outras mudanças de fase incluem a **vaporização** (líquido para gasoso), **condensação** (gasoso para líquido), **sublimação** (sólido para gasoso) e **deposição** (gasoso para sólido).

# %% [markdown]
# ### Propriedades das Substâncias
#
# Na termodinâmica, as propriedades das substâncias podem ser classificadas em duas categorias: propriedades extensivas e propriedades intensivas.
#
# **Propriedades extensivas:** São propriedades que dependem da quantidade de matéria no sistema. Elas são diretamente proporcionais à massa ou ao tamanho do sistema. Exemplos de propriedades extensivas incluem:
#
# - **Massa**: A quantidade de matéria em um sistema.
# - **Volume**: O espaço ocupado por um sistema.
# - **Energia interna**: A energia total de um sistema, incluindo energia cinética e potencial das partículas.
# - **Entalpia**: Uma medida da energia total de um sistema, incluindo a energia interna e o produto da pressão e do volume.
# - **Entropia**: Uma medida do grau de desordem de um sistema.
#
# Se um sistema for dividido em partes iguais, as propriedades extensivas dessas partes somadas serão iguais à propriedade extensiva do sistema original.
#
# **Propriedades intensivas:** São propriedades que não dependem da quantidade de matéria no sistema, ou seja, são independentes do tamanho ou da massa do sistema. Exemplos de propriedades intensivas incluem:
#
# - **Temperatura**: Uma medida da energia cinética média das partículas de um sistema.
# - **Pressão**: A força exercida por um sistema por unidade de área da fronteira do sistema.
# - **Densidade**: A massa por unidade de volume de uma substância.
# - **Capacidade calorífica específica**: A quantidade de energia necessária para aumentar a temperatura de uma unidade de massa de uma substância em um grau Celsius.
# - **Coeficiente de expansão térmica**: A variação relativa no tamanho de uma substância em função da variação na temperatura.
#
# As propriedades intensivas não mudam quando o sistema é dividido em partes menores. Elas são úteis para descrever e comparar o comportamento de diferentes sistemas, independentemente do tamanho ou da quantidade de matéria.
#
# **Obs:** Um conceito relacionado é o de propriedades específicas, que são propriedades extensivas normalizadas pela massa. Ao dividir uma propriedade extensiva pela massa, ela se torna uma propriedade intensiva. Por exemplo se dividir (Massa/Volume) que são duas propriendades exensivas então tal se torna uma propriedade intensiva a densidade.

# %% [markdown]
# ### Equilíbrio Térmico
#
# <img src="attachment:b4d5de4f-8dd8-4496-9c2b-1434cbc272df.png" alt="..." class="rounded float-end w-25 p-3 img-fluid" >
#
# Quando os primeiros métodos de quantificação da temperatura foram desenvolvidos, tornou-se possível estabelecer o que hoje chamamos de **equilíbrio térmico** em um sistema. Observou-se que, quando ``corpos quentes eram colocados em contato com corpos frios, o corpo mais quente se resfriava enquanto o corpo mais frio se aquecia``. Eventualmente, ``os dois corpos alcançavam uma temperatura comum, onde não se percebia mais nenhuma mudança na sensação térmica``. Esse estado é conhecido como equilíbrio térmico.

# %% [markdown]
# ## # Lei Zero

# %% [markdown]
# ---

# %% [markdown]
# A Lei Zero da Termodinâmica estabelece a base para a compreensão do conceito de equilíbrio térmico entre sistemas e é fundamental para a medição e comparação de temperaturas. A Lei Zero da Termodinâmica pode ser enunciada da seguinte maneira:
#
# <img src="attachment:92c2cbf6-17e7-4aa6-b0ed-dbca8d8ec6d5.png" alt="..." class="rounded float-end w-25 p-3 img-fluid" >
#
# *``Se dois sistemas estão em equilíbrio térmico com um terceiro sistema, então eles também estão em equilíbrio térmico entre si.``*

# %% [markdown]
# ## # Trabalho ($W$)

# %% [markdown]
# O trabalho (W) na termodinâmica é uma forma de energia transferida entre sistemas devido à aplicação de uma força através de uma distância. Não é uma propriedade, pois depende do caminho percorrido durante o processo termodinâmico. O trabalho pode ser realizado pelo sistema (sobre a vizinhança) ou sobre o sistema (pela vizinhança).
#
# Fórmula básica para calcular o trabalho:
#
# ### <center> $W = F \cdot d$
#
# Onde:
#
# - $W$ é o trabalho (Joules, J)
# - $F$ é a força (Newtons, N)
# - $d$ é a distância (metros, m)
#
# Em processos termodinâmicos, como isobáricos (pressão constante), isocóricos (volume constante), isotérmicos (temperatura constante) e adiabáticos (sem troca de calor), o trabalho é calculado usando a fórmula:
#
# ### <center> $W = -P \Delta V$
#
# Onde:
#
# - $W$ é o trabalho (Joules, J)
# - $P$ é a pressão (Pascal, Pa)
# - $\Delta V$ é a variação de volume (metros cúbicos, $m^3$)
#
#
# <img src="attachment:217dd046-22b9-4fd5-9e67-b9be600d99d7.png" alt="..." class="rounded float-end w-25 p-3 img-fluid" >
#
#
# A convenção de sinais para o trabalho é a seguinte:
#
# - $W < 0$: trabalho realizado pelo sistema (sobre a vizinhança)
# - $W > 0$: trabalho realizado sobre o sistema (pela vizinhança)
#
#
# Exemplo: Suponha que um gás esteja contido em um cilindro com êmbolo e uma força de 100 N seja aplicada ao êmbolo, deslocando-o 0,5 m para dentro do cilindro. O trabalho realizado pela vizinhança sobre o sistema é:
#
# ### <center> $W = F \cdot d = 100 \, N \cdot 0,5 \, m = 50 \, J$
#
# Nesse caso, o trabalho é positivo, pois é realizado sobre o sistema pela vizinhança.
#
# As unidades de trabalho e potência incluem:
#
# - Trabalho: 1 Joule (J) no SI e 1 pé-libra-força (ft·lbf) no Sistema Inglês
# - Potência: 1 Watt (W) = 1 J/s no SI, e 1 British Thermal Unit por hora (BTU/h), 1 pé-libra-força por hora (ft·lbf/h), e 1 cavalo-vapor (HP) = 746 W no Sistema Inglês.

# %% [markdown]
# ## # Energia

# %% [markdown]
# Na física, a energia é uma propriedade que descreve a capacidade de um objeto realizar trabalho ou ser convertida em outras formas de energia. Existem várias formas de energia, incluindo energia cinética e energia potencial.
#
# **Energia cinética (EK)** é a energia que um objeto possui devido ao seu movimento. A fórmula para calcular a energia cinética é:
#
# ### <center> $EK = \frac{1}{2}mv^2$
# Onde:
#
# - $EK$ é a energia cinética (Joules, J)
# - $m$ é a massa do objeto (quilogramas, kg)
# - $v$ é a velocidade do objeto (metros por segundo, m/s)
#
# **Energia potencial (EP)** é a energia armazenada em um objeto devido à sua posição em um campo de forças (como o campo gravitacional da Terra). A fórmula para calcular a energia potencial gravitacional é:
#
# ### <center> $EP = mgh$
#
# Onde:
#
# - $EP$ é a energia potencial (Joules, J)
# - $m$ é a massa do objeto (quilogramas, kg)
# - $g$ é a aceleração da gravidade (aproximadamente 9,81 m/s² na superfície da Terra)
# - $h$ é a altura do objeto em relação a um ponto de referência (metros, m)
#
# O Princípio da Conservação da Energia Mecânica estabelece que a soma das variações de energia cinética e energia potencial em um sistema fechado é zero na ausência de atrito ou outras forças não conservativas. Em outras palavras:
#
# ### <center> $ \Delta EK + \Delta EP = 0$
#
# Isso significa que, em um sistema fechado sem atrito, a energia mecânica total (energia cinética mais energia potencial) permanece constante.

# %% [markdown]
# ## # Calor

# %% [markdown]
# O calor é uma forma de energia que é transferida entre sistemas devido a diferenças de temperatura. O calor flui do sistema de maior temperatura para o de menor temperatura até que ambos atinjam um equilíbrio térmico.
#
# A quantidade de calor transferido é denotada por $Q$ e, assim como o trabalho, não é uma propriedade do sistema, mas sim uma quantidade que depende do caminho percorrido durante o processo termodinâmico.
#
#
# <img src="attachment:6ee4c973-4b4e-46db-8def-2af89630afc8.png" alt="..." class="rounded float-end w-25 p-3 img-fluid" >
#
# A convenção de sinais para o calor é a seguinte:
#
# - $Q > 0$: calor transferido para o sistema (absorvido pelo sistema)
# - $Q < 0$: calor transferido do sistema (liberado pelo sistema)
#
#
#
#
# Como o calor depende do caminho, sua variação $\Delta Q$ não pode ser diretamente relacionada às quantidades de calor nos estados 1 e 2. Ou seja:
#
#
# ### <center> $\Delta Q \neq Q_2 - Q_1$
#
# As unidades de medida para o calor são:
#
# - No Sistema Internacional (SI): Joules (J)
# - No Sistema Inglês: British Thermal Units (Btu) ou calorias (cal)
#
# Lembre-se de que o calor é uma energia em trânsito e não é uma propriedade do sistema. Portanto, não existe calor "no estado 2" nem "no estado 1", mas sim o calor transferido entre os estados.

# %% [markdown]
# ---

# %% [markdown]
# ### Exemplo 1.5 (semelhante aos exercícios 1.15 e 1.16):
# Um gás está confinado no interior de um cilindro por um pistão, diâmetro de 5 in, sobre o qual encontra-se um peso. A massa do pistão e do peso juntos é de 60 lbm. A aceleração da gravidade local é 32,13 ft/s2 , e a pressão da atmosfera é de 30,16 inHg.
#
# a)Qual é a força em lbf exercida sobre o gás pela atmosfera, o pistão e o peso, considerando que não há atrito entre o pistão e o cilindro?
#
# b)Qual a pressão (absoluta) do gás em psia?
#
# c)Se o gás no cilindro é aquecido, ele expande de forma que empurra o pistão e o peso para cima. Se o pistão e o peso são elevados 15 in, qual é o trabalho feito pelo gás em ft.lbf? Qual é a variação da energia potencial do pistão e do peso juntos?

# %% [markdown]
# #### Resposta

# %% [markdown]
# a) A força total exercida sobre o gás pelo peso, pistão e atmosfera é a soma da força do peso e do pistão com a força exercida pela pressão atmosférica.
#
# 1. Força do peso e do pistão:
#
# $$F_{peso+pistão} = m \times g$$
#
# Onde:
#
# - $m$ é a massa do pistão e do peso juntos (60 lbm)
# - $g$ é a aceleração da gravidade local (32,13 ft/s²)
#
#
# 2. Força exercida pela pressão atmosférica:
#
# A área da superfície do pistão é:
#
# $$A = \pi \left(\frac{d}{2}\right)^2$$
#
# - Onde $d$ é o diâmetro do pistão (5 in).
#
# A pressão atmosférica é dada em inHg. Para convertê-la em psi, usamos a conversão: 1 inHg = 0,491 psi. Então, a pressão atmosférica é:
#
# $$P_{atm} = 30,16 \, inHg \times 0,491 \frac{psi}{inHg}$$
#
# A força exercida pela pressão atmosférica é:
#
# $$F_{atm} = P_{atm} \times A$$
#
# Somando ambas as forças, obtemos a força total exercida sobre o gás:
#
# $$F_{total} = F_{peso+pistão} + F_{atm}$$
#
# b) Para calcular a pressão absoluta do gás em psia, primeiro precisamos encontrar a pressão manométrica:
#
# $$P_{man} = \frac{F_{total}}{A}$$
#
# Em seguida, adicionamos a pressão atmosférica para obter a pressão absoluta:
#
# $$P_{man} = \frac{F_{total}}{A}$$
#
# c) Para calcular o trabalho realizado pelo gás durante a expansão, usamos a fórmula do trabalho:
#
# $$\Delta V = A \times 15 \, in$$
#
# A variação de volume ($\Delta V$) pode ser encontrada multiplicando a área da base do pistão pela distância que o pistão se moveu (15 in):
#
# $$\Delta V_{ft^3} = \Delta V_{in^3} \times \frac{1 \, ft^3}{1728 \, in^3}$$
#
# Convertendo a variação de volume para pés cúbicos:
#
# $$W = -P_{man} \times \Delta V_{ft^3}$$
#
# Agora podemos calcular o trabalho em ft.lbf:
#
# $$\Delta h = \frac{15 \, in}{12 \frac{in}{ft}}$$
#
# A variação da energia potencial do pistão e do peso juntos pode ser calculada usando a fórmula da energia potencial:
#
# $$\Delta EP = m \times g \times \Delta h$$
#
#
# Onde $\Delta h$ é a variação de altura em pés. Para converter a variação de altura de 15 in para pés, utilizamos a conversão 1 ft = 12 in:
#
# $$\Delta h = \frac{15 \, in}{12 \frac{in}{ft}} = 1,25 \, ft$$
#
# Agora podemos calcular a variação da energia potencial do pistão e do peso juntos:
#
# $$\Delta EP = m \times g \times \Delta h = 60 \, lbm \times 32,13 \frac{ft}{s^2} \times 1,25 \, ft$$
