# %% [markdown]
# ---

# %% [markdown]
# <h3 align="center" style="color:gray">[1] Efeito da Temperatura no Cálculo de Reatores</h3>

# %% [markdown]
# ---

# %% [markdown]
# #### Relembrando a Primeira lei da termodinâmica:

# %% [markdown]
# Considere um sistema fechado, onde não existe troca com as vizinhanças. A variação da energia total do sistema é igual no fluxo de calor entrando menos o trabalho realizado pelo sistema nas vizinhanças.
#
# #### $$d_{E} = \delta Q - \delta W$$

# %% [markdown]
# ---

# %% [markdown]
# <h3 align="center" style="color:gray">Balanço de energia </h3>

# %% [markdown]
# ---

# %% [markdown]
# ##### Para sistemas contínuos o balanço de energia é:
#
# ![image.png](attachment:8394c43b-22c1-4956-ac79-d3162ce0e161.png)

# %% [markdown]
# Este tipo de sistema é aberto, pois existe troca de massa com as vizinhanças, assim temos que:
#
# ![image.png](attachment:61ea2a8d-31c0-4694-88eb-16265d6874bc.png)

# %% [markdown]
# Considerando $W = \dot{W_{S}}$,
# - ##### $\dot{W_{S}}$: Trabalho realizado por um misturador (reator de mistura), ou de uma turbina (reator tubular).

# %% [markdown]
# ![image.png](attachment:d8107a37-aa10-44e9-b20a-32ca9057283c.png)

# %% [markdown]
# Outras considerações:
# - ##### $Ei \simeq Ui$, sendo $Ui$ a energia interna.

# %% [markdown]
#  Portanto temos que, $Hi = Ui + PVi$

# %% [markdown]
# ![image.png](attachment:5f5324c6-2b57-46a8-b87c-66653273b11a.png)

# %% [markdown]
#
# #### Considerando esta reação e aplicando a equação (1):<center> $A + \frac{b}{a} B \rightarrow \frac{c}{a} C + \frac{d}{a} D$

# %% [markdown]
# Chegamos em,

# %% [markdown]
# ![image.png](attachment:6afdee49-ca82-46f0-9037-2241e39d69fc.png)

# %% [markdown]
# determinando o delta H da reação ($\Delta H_{R}(T)$):

# %% [markdown]
# ![image.png](attachment:20a6a8ac-1197-4620-a743-f24ef27a863a.png)

# %% [markdown]
# #### $$\sum_{N}^{i=1} H_{io}.F_{io} - \sum_{N}^{i=1} H_{i}.F_{i} = F_{ao} \sum_{n}^{i=1} \theta i (H_{io} - H_{i}) - \Delta H_{R} (T) . F_{ao} . X
# $$

# %% [markdown]
# Assim, chegamos que:
#
# ![image.png](attachment:2781eeb3-5bf8-4a81-8e07-214281fc8c36.png)

# %% [markdown]
# #### Para sistemas estacionários (EE):

# %% [markdown]
# ![image.png](attachment:6a90bcb3-e4fe-4f18-b64a-9b86ed585817.png)

# %% [markdown]
# Para o cálculo de reatores vamos negligenciar a variação das entalpias com a mistura e considerar que não há mudança de fase no reator:
# ![image.png](attachment:07176971-db14-44e9-8c65-9a8979cff91a.png)

# %% [markdown]
# Portanto iremos obter a seguinte equação:

# %% [markdown]
# ![image.png](attachment:413b9616-49ef-4c47-9c16-229c0248f72b.png)

# %% [markdown]
#  Para Cp constantes ou Cp médio, iremos utilizar:
#
# ![image.png](attachment:74df77bf-16e8-4361-9dd7-146b6debf107.png)

# %% [markdown]
# **Equação 02**:
#
# ![image.png](attachment:b5422ec2-c493-4b68-b4cb-4049af85dc45.png)

# %% [markdown]
# <h3 align="center" style="color:gray">[2] Efeito da Temperatura no Cálculo de Reatores</h3>

# %% [markdown]
# Para algumas misturas é necessario considerar a variação do Cp com a temperatura:

# %% [markdown]
# ![image.png](attachment:54e1d1f0-6fc3-4ce2-99fe-785e08c14980.png)

# %% [markdown]
# #### * Avaliando o termo do calor trocado($\dot{\theta}$):

# %% [markdown]
# Analisando a equação 02, temos:
#
# ![image.png](attachment:7cd8b184-5027-4568-a817-797a3dec0430.png)

# %% [markdown]
# #### * Avaliando o termo do calor trocado($\dot{\theta}$): **CSTR**

# %% [markdown]
# Para um reator de mistura em que, o fluido que faz a troca térmica entra na camisa do reator, a uma temperatura (Ta1) e sai a uma temperatura (Ta2) e a temperatura dentro do reator é T, o fluxo de calor da camisa para o reator é:

# %% [markdown]
# ![image.png](attachment:2075d8bb-32a1-47c6-ae23-f2f1f8a1a303.png)

# %% [markdown]
# #### * Avaliando o termo do calor trocado($\dot{\theta}$): **PFR**

# %% [markdown]
# No caso do reator tubular o calor ($\dot{\theta}$) será um pouco diferente:

# %% [markdown]
# ![image.png](attachment:a5e0c060-7b86-4afb-95b5-0dc9a0a03da2.png)

# %% [markdown]
# #### * Projeto de reatores contínuos, não isotérmicos, em estado estacionário:

# %% [markdown]
# Nesta seção iremos observar a interferência da temperatura no cálculo de reatores:
#
# - Considerando estado estacionário:
# #### $$\frac{dE}{dt} = 0$$
#
# - Considerando a operação adiabática: ``(sem troca de calor)``
# #### $$\dot{\theta} = 0$$
#
# - Desprezando o trabalho de eixo:
# #### $$\dot{W} = 0$$
#
# O balanço de energia, equação 02, fica:
#
# ![image.png](attachment:33c77c9d-fd54-4780-9ff1-ef3f395bd39a.png)

# %% [markdown]
# Esta equação é o balanço de energia, para projetar o reator precisamos acoplar o balanço de massa com o balanço de energia.

# %% [markdown]
# #### * Projeto de reatores contínuos, não isotérmicos, em estado estacionário: **CSTR (1)**

# %% [markdown]
# - Considerando o balanço de massa do reator de mistura:
#
# #### $$V=\frac{F_{ao}.X}{-R_{a}}$$
#
# - Considerando a reação de primeira ordem:
#     - #### $-R_{a} = K. Ca$
#     - #### Arrhenius: $K = A.e^{\frac{-Ea}{RT}} \rightarrow  ln(\frac{k1}{k2})= \frac{Ea}{R} . [\frac{1}{T2} - \frac{1}{T1}]$
#     - #### $Ca = Cao(1-X)$

# %% [markdown]
# Chegamos em:
#
# ![image.png](attachment:e413180a-0e77-46e7-94aa-d590ac5e519b.png)

# %% [markdown]
# Foi obtido que o volume depende da conversão (X) e da temperatura (T), para descobrir a temperatura iremos recorrer ao balanço de energia.

# %% [markdown]
# #### * Projeto de reatores contínuos, não isotérmicos, em estado estacionário: **CSTR (2)**

# %% [markdown]
# Para resolver a equação de projeto do CSTR (3), têmos que levar em conta os dados atribuidos ao sistema.

# %% [markdown]
# #### Caso 01:

# %% [markdown]
# - Foi dado: X, Q, Cao, Fio (Condições de entrada)
# - Foi pedido: V

# %% [markdown]
# 1. Resolver o balanço de energia: (Encontrar T, para vários Xi)
# 2. Calcular: K = f(T)
# 3. Resultado: (Calcular V a partir da equação de projeto)

# %% [markdown]
# #### Caso 02:

# %% [markdown]
# - Foi dado: V, Q, Cao, Fio (Condições de entrada)
# - Foi pedido: X e a composição de saída yi's

# %% [markdown]
# Para este caso têmos (Balanço de energia e massa), considerando a equação do balanço de massa (Bm) como de 1° ordem temos:

# %% [markdown]
# ![image.png](attachment:191c9904-7cc8-4461-87f0-bc1d4e845349.png)

# %% [markdown]
# ![image.png](attachment:7f96e606-ed82-44b1-94de-536446012f6a.png)

# %% [markdown]
# ![image.png](attachment:b008bbdf-94e6-4a64-857f-bb9aa3d8d557.png)
